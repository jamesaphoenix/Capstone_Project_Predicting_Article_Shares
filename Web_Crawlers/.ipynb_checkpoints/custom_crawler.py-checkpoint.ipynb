# %%
# Useful Libraries - https://github.com/codelucas/newspaper

# %%
#Importing Dependencies
import requests
from urllib.parse import urljoin, urlunsplit, urlparse
import bs4
from bs4 import BeautifulSoup
from bs4.element import Comment
from collections import Counter
from string import punctuation
import csv
import pandas as pd


#Tokenization Of Sentences
import nltk
nltk.download('punkt')

#Readability Scores
import textstat

# %%
urls = ['https://www.moneysavingexpert.com/travel/travel-tips/', 
        'https://www.moneysavingexpert.com/deals/deals-hunter/2018/05/how-to-get-free-cat-treats-and-other-pet-tips/', 
       'https://www.smartinsights.com/internet-advertising/internet-advertising-analytics/display-advertising-clickthrough-rates/'
       ]

# %%
class Crawler():
    def __init__(self, *args):
        self.urls = urls
        self.master_dict = {
            'URL':[],
            'Title_Text': [],
            'Title_Tag_Length': [],
            'Meta_Description': [],
            'Meta_Description_Length': [],
            'Content': [],
            'Word_Length': [],
            'Number_Of_Links': [],
            'Links_To_Text_Ratio': [],
            'Number_Of_Images':[],
            'H1_text': [],
            'H1_length': [],
            'H2_text': [],
            'H2_length': [],    
            'H3_text': [],
            'H3_length': [],    
            'H4_text': [],
            'H4_length': [],
            'H5_text': [],
            'H5_length': [],
            'lexicon_count': [],
            'Setences_Text': [],
            'Number_Of_Sentences': [],
            'Flesch_Reading_Ease_formula': [],
            'Flesch_Kincaid_Grade_Level': [],
            'FOG_Scale': [],
            'SMOG_Index': [],
            'ARI_Index': [],
            'Page_Size_In_Bytes': [],
            'Plain_Text_Size': [],
            'PLain_Text_Rate': [],
            'Encoding_Type': [],
            'Status_Code':[],
            'seo_friendly_url_characters_check': [],
            'seo_friendly_url_relative_length_check': [],
            'SSL/HTTPS': []
            
            ### Potential User Metrics ###
            #1.  User Comments (Text) 
            #2. Number of User Comments
            #3. User Comments Sentiment

            ### Page Speed Metrics ###
            #1. Meaningful Paint
            #2. Time To Interactive

            ### Link Metrics ###
            #1. DR 
            #2. PageURL Ranking 
            #3. Number of Referring Domains To Page
            #4. Number of Backlinks To Page
    
}        
        
        
    def get_metadata(self, soup):
        #Get Title Tag Of Page
        title_text = soup.title.getText()
        #Title Tag Length In Characters
        title_tag_length = len(title_text)
        # First get the meta description tag
        description = soup.find('meta', attrs={'name':'og:description'}) or soup.find('meta', attrs={'property':'description'}) or soup.find('meta', attrs={'name':'description'})
        # If description meta tag was found, then get the content attribute and save it to db entry
        if description:
            meta_description = description.get('content') 
        return Title_Text, title_tag_length, meta_description
    
    
    def extract_page_features(self, soup):
    # kill all script and style elements
        for script in soup(["script", "style"]):
            script.extract()    # rip it out

        # get text
        text = soup.body.get_text()

        # break into lines and remove leading and trailing space on each
        lines = (line.strip() for line in text.splitlines())
        # break multi-headlines into a line each
        chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
        # drop blank lines
        text = '\n'.join(chunk for chunk in chunks if chunk)

        #Word Length of The Webpage
        word_length = len(text)

        #Number of Links
        body_links = soup.body.find_all('a')
        number_of_links = len(body_links)

        #Links To Text Ratio
        links_to_text_ratio = len(body_links) / word_length

        #Number of Images
        Number_of_images = len([imgtag for imgtag in soup.body.find_all('img')])

        return text, word_length, body_links, number_of_links, links_to_text_ratio, Number_of_images
        
    
    def crawl(self, *args):
        for url in self.urls:
            
            #Loading BeautifulSoup
            req = requests.get(url)
            response = req.text
            soup = BeautifulSoup(response)
            
            #Meta_data
            meta_data = self.get_metadata(soup)
            for item in meta_data:
                if str(item) in                 

            self.master_dict['Title_Text'].append(meta_data[0])
            self.master_dict['Title_Tag_Length'].append(meta_data[1])
            self.master_dict['Meta_Description'].append(meta_data[2])
            
            #Extracting_Text_Features
            text_features = self.extract_page_features(soup)
            print(text_features)

# %%
crawler = Crawler(urls)

# %%
crawler.crawl()
# Out:
# ('We use cookies to make the site easier to use.\xa0Read our cookies policy\nI agree\nThe MoneySaving Forum:\xa0join to chat & swap tips with other MoneySavers. Learn how in the\xa0Forum Introduction Guide\nPure Money\nCredit Cards\xa0|\xa0Debt-Free Wannabe\xa0| Savings and Investments\nWork & Benefits\nUp Your Income\xa0|\xa0Benefits & Tax Credits\xa0|\xa0Employment & Jobseeking\nHome & Play\nUtilities\xa0|\xa0Old Style MoneySaving\xa0|\xa0 MoneySaving in Relationships\nWho & Where You Are\nOccasions & Celebrations\xa0|\xa0Student MoneySaving\xa0|\xa0Disability & Dosh\nBargains, Shopping & Freebies\nQuick! Grabbit\xa0|\xa0Shop don\'t drop\xa0|\xa0 Freebies\xa0|\xa0Competitions\nMoneySaving & Site\nSite Feedback\xa0|\xa0Martin\'s Blogs & Appearances Discussion\nMoneySavers Arms\nTime to relax...\nForum Home\nJoin 1000s of MoneySavers in the Forum\'s many discussion boards.\nWEEKLY EMAIL\nNEWS\nBLOGS\nMartin\'s Blog\nDeals Hunters\' Blog\nTeam Blog\nMSE STUFF\nAbout the site\nMSE FAQs\nThe MSE Charity Fund\nMoneySaving Quizzes\nHow we\'re financed\nMartin\'s Biography\nMartin\'s Online Gallery\nMoneySaving Polls\nSTUDENTS\nFINANCIAL ED\nCONTACT US\nFORUM\nsearch\nall guides news deals blogs weekly email forum\nMoneySavingExpert.com\nFounder & Chair, Martin Lewis · Editor-in-Chief, Marcus Herbert\nFacebook\nTwitter\nYoutube\nInstagram\nLinkedIn\nMoneySavingExpert.com\nFOUNDER & CHAIR, MARTIN LEWIS\nThe MSE mobile menu (not all pages are optimised yet)\nLatest Money Tips Email\nCards & Loans\nGo to full Cards & Loans section\nCards & Loans\nGo to full Cards & Loans section\nReclaim £1,000s\nGo to full Reclaim £1,000s section\nReclaim £1,000s\nGo to full Reclaim £1,000s section\nUtilities & Phones\nGo to full Utilities & Phones section\nUtilities & Phones\nGo to full Utilities & Phones section\nBanking & Saving\nGo to full Banking & Saving section\nBanking & Saving\nGo to full Banking & Saving section\nDeals & Vouchers\nGo to full Deals & Vouchers section\nDeals & Vouchers\nGo to full Deals & Vouchers section\nTravel & Motoring\nGo to full Travel & Motoring section\nTravel & Motoring\nGo to full Travel & Motoring section\nInsurance\nGo to full Insurance section\nInsurance\nGo to full Insurance section\nMortgages & Homes\nGo to full Mortgages & Homes section\nMortgages & Homes\nGo to full Mortgages & Homes section\nShopping\nGo to full Shopping section\nShopping\nGo to full Shopping section\nIncome & Family\nGo to full Income & Family section\nIncome & Family\nGo to full Income & Family section\nForum\nNews\nBlog\nStudents\nFinancial Ed.\nMSE Stuff\nContact Us\nGo to full section\nGo to full section\nCards & Loans\nGo to full Cards & Loans section\nCredit Cards\n0% Credit Cards for Spending\nBalance Transfer Credit Cards\nMSE Credit Club\nCredit Card Eligibility Calculator\nCredit cards for Bad Credit\nCashback & Rewards\nRewards Eligibility Calculator\nBest Card Rewards\nAirline Credit Cards\nTravel Credit Cards\nStoozing – make free cash\nLoans\nCheap Loans\nLoans Eligibility Calculator\nFree Credit Report\nHow to Improve Credit Scores\nCut Loan Costs\nDebt Help\nDebt Problems\nMental Health Debt Guide\nDont Bank With Debts\nDebt Solutions\nMoney Makeover\nTools & Calculators\nMSE Credit Club\nEligibility Calculator\nLoan Calculator\nBalance Transfer Calculator\nMinimum repayments calculator\nNews\nStudent loan repayment thresholds…\nBarclaycard cans free overseas…\nBest Buys & Calculators\nBalance Transfers\nShift existing credit or store card debt to 0% interest, saving you £100s\nCheap Loans\nThe best rates if you NEED to borrow\nMSE Credit Club\nGet your free Experian Credit Report and Credit Score, unique Affordability Score + tips to boost \'em\nCredit Card & Loan Eligibility Calculator\nOur Eligibility Calcs check your chances of getting cards & loans.\nCards & Loans\nGo to full Cards & Loans section\nReclaim £1,000s\nGo to full Reclaim £1,000s section\nBig Reclaims\nReclaim PPI for Free\nReclaim Packaged Bank Accounts\nCo ...
# <!--[if IE 9]><video style="display: none;"><![endif]--><source media="(min-width: 0px) and (max-width: 319px)" srcset="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.320.320.png"/>
# <source media="(min-width: 320px) and (max-width: 479px)" srcset="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.480.480.png"/>
# <source media="(min-width: 480px) and (max-width: 767px)" srcset="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.768.768.png"/>
# <source media="(min-width: 768px) and (max-width: 1199px)" srcset="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.768.768.png"/>
# <source media="(min-width: 1200px)" srcset="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.992.992.png"/>
# <!--[if IE 9]></video><![endif]--><img alt="" src="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.320.320.png"/>
# </picture>
# </a>, <a href="https://www.moneysavingexpert.com/">MoneySavingExpert.com</a>, <a href="https://www.moneysavingexpert.com/"><em>Founder &amp; Chair, Martin Lewis · Editor-in-Chief, Marcus Herbert</em></a>, <a href="https://www.moneysavingexpert.com/site/money-tips-email-faqs"> <picture>
# <!--[if IE 9]><video style="display: none;"><![endif]--><source media="(min-width: 0px) and (max-width: 319px)" srcset="/content/dam/mse-demo/header-social-martin.png.rendition.320.320.png"/>
# <source media="(min-width: 320px) and (max-width: 479px)" srcset="/content/dam/mse-demo/header-social-martin.png.rendition.480.480.png"/>
# <source media="(min-width: 480px) and (max-width: 767px)" srcset="/content/dam/mse-demo/header-social-martin.png.rendition.768.768.png"/>
# <source media="(min-width: 768px) and (max-width: 1199px)" srcset="/content/dam/mse-demo/header-social-martin.png.rendition.768.768.png"/>
# <source media="(min-width: 1200px)" srcset="/content/dam/mse-demo/header-social-martin.png.rendition.992.992.png"/>
# <!--[if IE 9]></video><![endif]--><img alt="" src="/content/dam/mse-demo/header-social-martin.png.rendition.320.320.png"/>
# </picture>
# </a>, <a class="header-social-facebook" href="https://www.facebook.com/MoneySavingExpert" rel="noopener noreferer" target="_blank">Facebook</a>, <a class="header-social-twitter" href="https://twitter.com/MoneySavingExp" rel="noopener noreferer" target="_blank">Twitter</a>, <a class="header-social-youtube" href="https://www.youtube.com/channel/UC5CDoveqvEuQsW3x-DnYtww" rel="noopener noreferer" target="_blank">Youtube</a>, <a class="header-social-instagram" href="https://instagram.com/moneysavingexp" rel="noopener noreferer" target="_blank">Instagram</a>, <a class="header-social-linkedin" href="https://www.linkedin.com/company/moneysavingexpert-com" rel="noopener noreferer" target="_blank">LinkedIn</a>, <a aria-hidden="true" id="1221221062" style="visibility:hidden"></a>, <a aria-hidden="true" id="328118892" style="visibility:hidden"></a>, <a href="https://www.moneysavingexpert.com/">MoneySavingExpert.com</a>, <a href="https://www.moneysavingexpert.com/">FOUNDER &amp; CHAIR, MARTIN LEWIS</a>, <a aria-hidden="true" id="01058122244" style="visibility:hidden"></a>, <a href="https://www.moneysavingexpert.com/latesttip/">Latest Money Tips Email</a>, <a aria-hidden="true" id="01732025567" style="visibility:hidden"></a>, <a class="cards" href="https://www.moneysavingexpert.com/borrowing/"> <span>Cards &amp; Loans</span> </a>, <a class="cards go-to-full-section" href="https://www.moneysavingexpert.com/borrowing/"> <span>Go to full Cards &amp; Loans section</span> </a>, <a class="cards" href="https://www.moneysavingexpert.com/borrowing/"> <span>Cards &amp; Loans</span> </a>, <a class="cards go-to-full-section" href="https://www.moneysavingexpert.com/borrowing/"> <span>Go to full Cards &amp; Loans section</span> </a>, <a class="reclaim" href="https://www.moneysavingexpert.com/reclaim/"> <span>Reclaim £1,000s</span> </a>, <a class="reclaim go-to-full-section" href="https://www.moneysavingexpert.com/reclaim/"> <span>Go to full Reclaim £1,000s section</span> </a>, <a class="reclaim" href="https://www.moneysavingexpert.com/reclaim/"> <span>Reclaim £1,000s</span> </a>, <a class="reclaim go-to-full-section" href="https://www.moneysavingexpert.com/reclaim/"> <span>Go to full Reclaim £1,000s section</span> </a>, <a class="utilities" href="https://www.moneysavingexpert.com/utilities/"> <span>Utilities &amp; Phones</span> </a>, <a class="utilities go-to-full-section" href="https://www.moneysavingexpert.com/utilities/"> <span>Go to full Utilities &amp; Phones section</span> </a>, <a class="utilities" href="https://www.moneysavingexpert.com/utilities/"> <span>Utilities &amp; Phones</span> </a>, <a class="utilities go-to-full-section" href="https://www.moneysavingexpert.com/utilities/"> <span>Go to full Utilities &amp; Phones section</span> </a>, <a class="banking" href="https://www.moneysavingexpert.com/banking/"> <span>Banking &amp; Saving</span> </a>, <a class="banking go-to-full-section" href="https://www.moneysavingexpert.com/banking/"> <span>Go to full Banking &amp; Saving section</span> </a>, <a class="banking" href="https://www.moneysavingexpert.com/banking/"> <span>Banking &amp; Saving</span> </a>, <a class="banking go-to-full-section" href="https://www.moneysavingexpert.com/banking/"> <span>Go to full Banking &amp; Saving section</span> </a>, <a class="deals" href="https://www.moneysavingexpert.com/deals/"> <span>Deals &amp; Vouchers</span> </a>, <a class="deals go-to-full-section" href="https://www.moneysavingexpert.com/deals/"> <span>Go to full Deals &amp; Vouchers section</span> </a>, <a class="deals" href="https://www.moneysavingexpert.com/deals/"> <span>Deals &amp; Vouchers</span> </a>, <a class="deals go-to-full-section" href="https://www.moneysavingexpert.com/deals/"> <span>Go to full Deals &amp; Vouchers section</span> </a>, <a class="travel" href="https://www.moneysavingexpert.com/travel/"> <span>Travel &amp; Motoring</span> </a>, <a class="travel go-to-full-section" href="https://www.moneysavingexpert.com/travel/"> <span>Go to full ...
# <img alt="Extra 25% off Kurt Geiger outlet" src="/content/dam/mse/deals/shoeaholics-logo-july-2016.jpg"/>
# </a>, <a class="dealsPriorityList-link-title" href="https://www.moneysavingexpert.com/deals/shoeaholics/#51770" title="Extra 25% off Kurt Geiger outlet">Extra 25% off Kurt Geiger outlet</a>, <a class="dealsPriorityList-link-description" href="https://www.moneysavingexpert.com/deals/shoeaholics/#51770" title="Via code valid on everything">Via code valid on everything</a>, <a class="dealsPriorityList-image" href="https://www.moneysavingexpert.com/deals/boohoo/#51811">
# <img alt="Boohoo 5% EXTRA off code" src="/content/dam/mse/deals/boohoo-logo-march-2017-200x200.jpg"/>
# </a>, <a class="dealsPriorityList-link-title" href="https://www.moneysavingexpert.com/deals/boohoo/#51811" title="Boohoo 5% EXTRA off code">Boohoo 5% EXTRA off code</a>, <a class="dealsPriorityList-link-description" href="https://www.moneysavingexpert.com/deals/boohoo/#51811" title="Valid on its 'up to 80% off' sale">Valid on its 'up to 80% off' sale</a>, <a class="dealsPriorityList-image" href="https://www.moneysavingexpert.com/deals/naked-wines/#51802">
# <img alt="Naked Wines £35 case" src="/content/dam/mse/deals/NakedWines2017Logo.png"/>
# </a>, <a class="dealsPriorityList-link-title" href="https://www.moneysavingexpert.com/deals/naked-wines/#51802" title="Naked Wines £35 case">Naked Wines £35 case</a>, <a class="dealsPriorityList-link-description" href="https://www.moneysavingexpert.com/deals/naked-wines/#51802" title="7 bottles and 2 glasses">7 bottles and 2 glasses</a>, <a class="deals" href="https://www.moneysavingexpert.com/deals/"> <span>Deals &amp; Vouchers</span> </a>, <a class="deals go-to-full-section" href="https://www.moneysavingexpert.com/deals/"> <span>Go to full Deals &amp; Vouchers section</span> </a>, <a class="travel" href="https://www.moneysavingexpert.com/travel/"> <span>Travel &amp; Motoring</span> </a>, <a class="travel go-to-full-section" href="https://www.moneysavingexpert.com/travel/"> <span>Go to full Travel &amp; Motoring section</span> </a>, <a aria-hidden="true" id="01683309790" style="visibility:hidden"></a>, <a href="https://www.moneysavingexpert.com/travel/cheap-flights/">Cheap Flights</a>, <a href="https://www.moneysavingexpert.com/travel
-refunds---wi/">Hundreds of ex-Virgin One mortgage…</a>, <a href="https://www.moneysavingexpert.com/news/2019/07/-my-credit-file-doppelganger-meant-i-was-hounded-by-bailiffs-and/">'I was hounded by bailiffs…</a>, <a aria-hidden="true" id="2124388677" style="visibility:hidden"></a>, <a href="https://www.moneysavingexpert.com/mortgages/best-buys/">Mortgage Best Buys Tool</a>, <a href="https://www.moneysavingexpert.com/mortgages/mortgage-overpayment-calculator">Overpayments Calculator</a>, <a href="https://www.moneysavingexpert.com/mortgages/how-much-mortgage-borrowing/">How Much Can I Borrow?</a>, <a href="https://www.moneysavingexpert.com/mortgages/mortgage-rate-calculator">More...</a>, <a class="mortgages" href="https://www.moneysavingexpert.com/mortgages/"> <span>Mortgages &amp; H ...
# <div class="tip-div">
# <div class="tip-title-div">Big 6 energy price war</div>
# <div class="tip-text-div">British Gas vs EDF. Who wins?</div>
# <div class="tip-image-div">
# <img alt="Big 6 energy price war" class="tip-image" src="https://images6.moneysavingexpert.com/images/mmt_rhs-energynew.png"/>
# </div>
# </div>
# </a>, <a href="https://www.moneysavingexpert.com/latesttip/#loans">
# <div class="tip-div">
# <div class="tip-title-div">Cheapest EVER loan £5k-£7,499</div>
# <div class="tip-text-div">At 3.2%</div>
# <div class="tip-image-div">
# <img alt="Cheapest EVER loan £5k-£7,499" class="tip-image" src="https://images6.moneysavingexpert.com/images/mmt_rhs-green-cash-2.png"/>
# </div>
# </div>
# </a>, <a href="https://www.moneysavingexpert.com/latesttip/#carins">
# <div class="tip-div">
# <div class="tip-title-div">'I saved £1k thanks to car insurance trick'</div>
# <div class="tip-text-div">Here's when to renew</div>
# <div class="tip-image-div">
# <img alt="'I saved £1k thanks to car insurance trick'" class="tip-image" src="https://images6.moneysavingexpert.com/images/mmt_rhs-multicar.jpg"/>
# </div>
# </div>
# </a>, <a href="https://www.moneysavingexpert.com/latesttip/#delay">
# <div class="tip-div">
# <div class="tip-title-div">£100m train compensation unclaimed </div>
# <div class="tip-text-div">Here are you rights</div>
# <div class="tip-image-div">
# <img alt="£100m train compensation unclaimed " class="tip-image" src="https://images6.moneysavingexpert.com/images/mmt_rhs-railcard.jpg"/>
# </div>
# </div>
# </a>, <a href="https://www.moneysavingexpert.com/latesttip/#ppi">
# <div class="tip-div">
# <div class="tip-title-div">'I reclaimed £250,000 in PPI'</div>
# <div class="tip-text-div">The most we've ever seen</div>
# <div class="tip-image-div">
# <img alt="'I reclaimed £250,000 in PPI'" class="tip-image" src="https://images6.moneysavingexpert.com/images/mmt_rhs-ppi.png"/>
# </div>
# </div>
# </a>, <a href="https://www.moneysavingexpert.com/latesttip/#theatre">
# <div class="tip-div">
# <div class="tip-title-div">Top-secret theatre tickets from £4</div>
# <div class="tip-text-div">If you can keep schtum</div>
# <div class="tip-image-div">
# <img alt="Top-secret theatre tickets from £4" class="tip-image" src="https://images6.moneysavingexpert.com/images/mmt_rhs-theatre .png"/>
# </div>
# </div>
# </a>, <a href="https://www.moneysavingexpert.com/latesttip/#coupons">
# <div class="tip-div">
# <div class="tip-title-div">70+ supermarket coupons</div>
# <div class="tip-text-div">Incl free Persil washing device</div>
# <div class="tip-image-div">
# <img alt="70+ supermarket coupons" class="tip-image" src="https://images6.moneysavingexpert.com/images/mmt_Artboard 24 copy 2-8.png"/>
# </div>
# </div>
# </a>, <a href="https://www.moneysavingexpert.com/latesttip/#holsalert">
# <div class="tip-div">
# <div class="tip-title-div">Why wearing flip-flops could land you with a fine</div>
# <div class="tip-text-div">When you're on holiday</div>
# <div class="tip-image-div">
# <img alt="Why wearing flip-flops could land you with a fine" class="tip-image" src="https://images6.moneysavingexpert.com/images/mmt_RHS-flip-flops.png"/>
# </div>
# </div>
# </a>, <a href="https://www.moneysavingexpert.com/site/money-tips-email-faqs">FAQs</a>, <a href="https://www.moneysavingexpert.com/site/privacy-policy">Privacy Policy</a>, <a href="https://www.moneysavingexpert.com/archive">Past Emails</a>, <a href="https://www.moneysavingexpert.com/unsubscribe/">Unsubscribe</a>, <a href="#tab-0898145795-0">
# <div class="tabMenuItem component section color-news analytics-item_0 item_0">
# <div class="">
# <span class="text-wrapper">MSE News</span>
# </div>
# </div> </a>, <a href="#tab-0898145795-1">
# <div class="tabMenuItem component section color-martins-blog analytics-item_1 item_1">
# <div class="">
# <span class="text-wrapper">Martin's Blog</span>
# </div>
# </div> </a>, <a href="#tab-0898145795-2">
# <div class="tabMenuItem component section color-deal-hunters analytics-item_2 item_2">
# <div class="">
# <span class="text-wrapper">Deals Blog</span>
# </div>
# </div> </a>, <a aria-hidden="true" id="839436519" style="visibility:hidden"></a>, <a href="https://www.moneysavingexpert.com/news/2019/08/first-of-the-big-six-cuts-energy-prices-following-ofgem-s-price-/">First of the big six reveals cut to energy bills after price cap drop – but you could save £100s/yr by switching</a>, <a href="https://www.moneysavingexpert.com/news/2019/08/first-of-the-big-six-cuts-energy-prices-following-ofgem-s-price-/"> <img alt="" class="articleList-thumbnail" src="/content/dam/mse/editorial-image-library/guide-images/rhs-guide-images-/rhs-utilities-energy-misselling.jpg.rendition.320.320.jpg"/>
# </a>, <a href="https://www.moneysavingexpert.com/news/2019/08/ex-solarplicity-customers-to-get-compensation-after-being-wrongl/">Ex-Solarplicity customers wrongly switched to Toto Energy</a>, <a href="https://www.moneysavingexpert.com/news/2019/08/ex-solarplicity-customers-to-get-compensation-after-being-wrongl/"> <img alt="" class="articleList-thumbnail" src="/content/dam/rhs-energy-cap%20.png.rendition.320.320.png"/>
# </a>, <a href="https://www.moneysavingexpert.com/news/2019/08/lidl-launches-reusable-fruit-and-veg-bags/">Lidl launches reusable fruit and veg bags</a>, <a href="https://www.moneysavingexpert.com/news/2019/08/lidl-launches-reusable-fruit-and-veg-bags/"> <img alt="" class="articleList-thumbnail" src="/content/dam/rhs-lidl-veg-bag.jpg.rendition.320.320.jpg"/>
# </a>, <a href="https://www.moneysavingexpert.com/news/2019/08/320-000-nationwide-customers-owed-refunds-for-overdraft-charges/">320,000 Nationwide customers owed average £19 refund for overdraft charges</a>, <a href="https://www.moneysavingexpert.com/news/2019/08/320-000-nationwide-customers-owed-refunds-for-overdraft-charges/"> <img alt="" class="articleList-thumbnail" src="/content/dam/mse/migrated/news/nationwide.jpg.rendition.320.320.jpg"/>
cans free overseas…\nBest Buys & Calculators\nBalance Transfers\nShift existing credit or store card debt to 0% interest, saving you £100s\nCheap Loans\nThe best rates if you NEED to borrow\nMSE Credit Club\nGet your free Experian Credit Report and Credit Score, unique Affordability Score + tips to boost 'em\nCredit Card & Loan Eligibility Calculator\nOur Eligibility Calcs check your chances of getting cards & loans.\nCards & Loans\nGo to full Cards & Loans section\nReclaim £1,000s\nGo to full Reclaim £1,000s section\nBig Reclaims\nReclaim PPI for Free\nReclaim Packaged Bank Accounts\nCouncil Tax ...
# <!--[if IE 9]><video style="display: none;"><![endif]--><source media="(min-width: 0px) and (max-width: 319px)" srcset="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.320.320.png"/>
# <source media="(min-width: 320px) and (max-width: 479px)" srcset="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.480.480.png"/>
# <source media="(min-width: 480px) and (max-width: 767px)" srcset="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.768.768.png"/>
# <source media="(min-width: 768px) and (max-width: 1199px)" srcset="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.768.768.png"/>
# <source media="(min-width: 1200px)" srcset="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.992.992.png"/>
# <!--[if IE 9]></video><![endif]--><img alt="" src="/content/dam/mse/page-furniture/header-social-cutting-cost.png.rendition.320.320.png"/>
# </picture>
# </a>, <a href="https://www.moneysavingexpert.com/">MoneySavingExpert.com</a>, <a href="https://www.moneysavingexpert.com/"><em>Founder &amp; Chair, Martin Lewis · Editor-in-Chief, Marcus Herbert</em></a>, <a href="https://www.moneysavingexpert.com/site/money-tips-email-faqs"> <picture>
# <!--[if IE 9]><video style="display: none;"><![endif]--><source media="(min-width: 0px) and (max-width: 319px)" srcset="/content/dam/mse-demo/header-social-martin.png.rendition.320.320.png"/>
# <source media="(min-width: 320px) and (max-width: 479px)" srcset="/content/dam/mse-demo/header-social-martin.png.rendition.480.480.png"/>
# <source media="(min-width: 480px) and (max-width: 767px)" srcset="/content/dam/mse-demo/header-social-martin.png.rendition.768.768.png"/>
# <source media="(min-width: 768px) and (max-width: 1199px)" srcset="/content/dam/mse-demo/header-social-martin.png.rendition.768.768.png"/>
# <source media="(min-width: 1200px)" srcset="/content/dam/mse-demo/header-social-martin.png.rendition.992.992.png"/>
# <!--[if IE 9]></video><![endif]--><img alt="" src="/content/dam/mse-demo/header-social-martin.png.rendition.320.320.png"/>
# </picture>
# </a>, <a class="header-social-facebook" href="https://www.facebook.com/MoneySavingExpert" rel="noopener noreferer" target="_blank">Facebook</a>, <a class="header-social-twitter" href="https://twitter.com/MoneySavingExp" rel="noopener noreferer" target="_blank">Twitter</a>, <a class="header-social-youtube" href="https://www.youtube.com/channel/UC5CDoveqvEuQsW3x-DnYtww" rel="noopener noreferer" target="_blank">Youtube</a>, <a class="header-social-instagram" href="https://instagram.com/moneysavingexp" rel="noopener noreferer" target="_blank">Instagram</a>, <a class="header-social-linkedin" href="https://www.linkedin.com/company/moneysavingexpert-
# <img alt="Extra 25% off Kurt Geiger outlet" src="/content/dam/mse/deals/shoeaholics-logo-july-2016.jpg"/>
# </a>, <a class="dealsPriorityList-link-title" href="https://www.moneysavingexpert.com/deals/shoeaholics/#51770" title="Extra 25% off Kurt Geiger outlet">Extra 25% off Kurt Geiger outlet</a>, <a class="dealsPriorityList-link-description" href="https://www.moneysavingexpert.com/deals/shoeaholics/#51770" title="Via code valid on everything">Via code valid on everything</a>, <a class="dealsPriorityList-image" href="https://www.moneysavingexpert.com/deals/boohoo/#51811">
# <img alt="Boohoo 5% EXTRA off code" src="/content/dam/mse/deals/boohoo-logo-march-2017-200x200.jpg"/>
# </a>, <a class="dealsPriorityList-link-title" href="https://www.moneysavingexpert.com/deals/boohoo/#51811" title="Boohoo 5% EXTRA off code">Boohoo 5% EXTRA off code</a>, <a class="dealsPriorityList-link-description" href="https://www.moneysavingexpert.com/deals/boohoo/#51811" title="Valid on its 'up to 80% off' sale">Valid on its 'up to 80% off' sale</a>, <a class="dealsPriorityList-image" href="https://www.moneysavingexpert.com/deals/naked-wines/#51802">
# <img alt="Naked Wines £35 case" src="/content/dam/mse/deals/NakedWines2017Logo.png"/>
# ...
# Charity and Not-for-profit organisations </a>, <a href="https://www.smartinsights.com/improve/content-marketing-toolkit/" onclick="ga('send','event','Blog link','Clicked individual', 'Content Marketing');" title="Content Marketing">
# Content Marketing </a>, <a href="https://www.smartinsights.com/improve/digital-experience-management-toolkit/" onclick="ga('send','event','Blog link','Clicked individual', 'Digital Experience Management');" title="Digital Experience Management">
# Digital Experience Management </a>, <a href="https://www.smartinsights.com/improve/digital-marketing-strategy-planning-toolkit/" onclick="ga('send','event','Blog link','Clicked individual', 'Digital Marketing Strategy and Planning');" title="Digital Marketing Strategy and Planning">
# Digital Marketing Strategy and Planning </a>, <a href="https://www.smartinsights.com/improve/digital-transformation-toolkit/" onclick="ga('send','event','Blog link','Clicked individual', 'Digital Transformation');" title="Digital Transformation">
# Digital Transformation </a>, <a href="https://www.smartinsights.com/improve/ecommerce-retail-digital-marketing/" onclick="ga('send','event','Blog link','Clicked individual', 'E-commerce and Retail Digital Marketing');" title="E-commerce and Retail Digital Marketing">
# E-commerce and Retail Digital Marketing </a>, <a href="https://www.smartinsights.com/improve/email-marketing-toolkit/" onclick="ga('send','event','Blog link','Clicked individual', 'Email Marketing and Marketing Automation');" title="Email Marketing and Marketing Automation">
# Email Marketing and Marketing Automation </a>, <a href="https://www.smartinsights.com/improve/google-adwords-toolkit/" onclick="ga('send','event','Blog link','Clicked individual', 'Google AdWords');" title="Google AdWords">
# Google AdWords </a>, <a href="https://www.smartinsights.com/improve/google-analytics-toolkit/" onclick="ga('send','event','Blog link','Clicked individual', 'Google Analytics');" title="Google Analytics">
# Google Analytics </a>, <a href="https://www.smartinsights.com/improve/managing-digital-branding/" onclick="ga('send','event','Blog link','Clicked individual', 'Managing Digital Branding');" title="Managing Digital Branding">
# Managing Digital Branding </a>, <a href="https://www.smartinsights.com/improve/managing-digital-marketing-teams/" onclick="ga('send','event','Blog link','Clicked individual', 'Managing Digital Marketing Teams');" title="Managing Digital Marketing Teams">
# Managing Digital Marketing Teams </a>, <a href="https://www.smartinsights.com/improve/managing-international-marketing/" onclick="ga('send','event','Blog link','Clicked individual', 'Managing International Marketing');" title="Managing International Marketing">
# Managing International Marketing </a>, <a href="https://www.smartinsights.com/improve/marketing-campaign-planning-toolkit/" onclick="ga('send','event','Blog link','Clicked individual', 'Marketing Campaign Planning');" title="Marketing Campaign Planning">
# Marketing Campaign Planning </a>, <a href="https://www.smartinsights.com/improve/marketing-strategy-planning/" onclick="ga('send','event','Blog link','Clicked individual', 'Marketing Strategy and Planning');" title="Marketing Strategy and Planning">
# Marketing Strategy and Planning </a>, <a href="https://www.smartinsights.com/improve/multichannel-lifecycle-marketing/" onclick="ga('send','event','Blog link','Clicked individual', 'Multichannel lifecycle marketing');" title="Multichannel lifecycle marketing">
# Multichannel lifecycle marketing </a>, <a href="https://www.smartinsights.com/improve/paid-media/" onclick="ga('send','event','Blog link','Clicked individual', 'Paid media');" title="Paid media">
# Paid media </a>, <a href="https://www.smartinsights.com/improve/search-engine-optimisation-seo-toolkit/" onclick="ga('send','event','Blog link','Clicked individual', 'Search Engine Optimisation (SEO)');" title="Search Engine Optimisation (SEO)">
# Search Engine Optimisation (SEO) </a>, <a href="https://www.smartinsights.com/improve/sector-technology-innovation/" onclick="ga('send','event','Blog link','Clicked individual', 'Sector Technology Innovation');" title="Sector Technology Innovation">
# Sector Technology Innovation </a>, <a href="https://www.smartinsights.com/improve/social-media-marketing-toolkit/" onclick="ga('send','event','Blog link','Clicked individual', 'Social Media Marketing');" title="Social Media Marketing">
# Social Media Marketing </a>, <a href="https://www.smartinsights.com/improve/start-up-and-small-business-toolkits/" onclick="ga('send','event','Blog link','Clicked individual', 'Startups and small business');" title="Startups and small business">
# Startups and small business </a>, <a href="https://www.smartinsights.com/internet-advertising/internet-advertising-analytics/uk-online-ad-spend-latest-statistics-released/" onclick="ga('send','event','Blog link','Clicked individual', 'UK Online Ad Spend : Latest statistics released');" title="UK Online Ad Spend : Latest statistics released">
# UK Online Ad Spend : Latest statistics released </a>, <a href="https://www.smartinsights.com/internet-advertising/internet-advertising-analytics/paid-social-media-advertising-is-it-worthwhile/" onclick="ga('send','event','Blog link','Clicked individual', 'Paid social media advertising: Is it worthwhile?');" title="Paid social media advertising: Is it worthwhile?">
# Paid social media advertising: Is it worthwhile? </a>, <a href="https://www.smartinsights.com/internet-advertising/internet-advertising-targeting/what-is-programmatic-marketing/" onclick="ga('send','event','Blog link','Clicked individual', 'What is Programmatic Marketing?');" title="What is Programmatic Marketing?">
# What is Programmatic Marketing? </a>, <a href="https://www.smartinsights.com/internet-advertising/ad-networks/social-media-ad-spending-trends-infographic/" onclick="ga('send','event','Blog link','Clicked individual', 'Social Media Ad Spending Trends [Infographic]');" title="Social Media Ad Spending Trends [Infographic]">
# Social Media Ad Spending Trends [Infographic] </a>, <a href="https://www.smartinsights.com/social-media-marketing/twitter-marketing/twitter-advertising-campaign-costs/" onclick="ga('send','event','Blog link','Clicked individual', 'Twitter advertising campaign costs');" title="Twitter advertising campaign costs">
# Twitter advertising campaign costs </a>, <a href="https://www.smartinsights.com/internet-advertising/internet-advertising-strategy/uncover-art-media-spend-artificial-intelligence/" onclick="ga('send','event','Blog link','Clicked individual', 'Uncover the Art of Media Spend With Artificial Intelligence and Machine Learning');" title="Uncover the Art of Media Spend With Artificial Intelligence and Machine Learning">
# Uncover the Art of Media Spend With Artificial Intelligence and Machine Learning </a>, <a href="https://www.smartinsights.com/internet-advertising/internet-advertising-analytics/attribution-measurement-from-ads-infographic/" onclick="ga('send','event','Blog link','Clicked individual', 'Attribution measurement from Ads (Infographic)');" title="Attribution measurement from Ads (Infographic)">
# Attribution measurement from Ads (Infographic) </a>, <a href="https://www.smartinsights.com/online-brand-strategy/international-marketing/new-global-ad-spend-by-sector-results/" onclick="ga('send','event','Blog link','Clicked individual', 'New Global Ad Spend by Sector results');" title="New Global Ad Spend by Sector results">
# New Global Ad Spend by Sector results </a>, <a href="https://www.smartinsights.com/social-media-marketing/facebook-marketing/facebook-advertising-clickthrough-rates/" onclick="ga('send','event','Blog link','Clicked individual', 'Facebook advertising clickthrough rates');" title="Facebook advertising clickthrough rates">
# Facebook advertising clickthrough rates </a>, <a href="https://www.smartinsights.com/internet-advertising/most-effective-advertising-formats/" onclick="ga('send','event','Blog link','Clicked individual', 'Which are the most effective advertising formats today?');" title="Which are the most effective advertising formats today?">
# Which are the most effective advertising formats today? </a>, <a class="btn btn-default btn-md" href="https://www.smartinsights.com/archive/internet-advertising/internet-advertising-analytics/" onclick="ga('send','event','Blog link','Clicked main CTA', 'view all articles');">
# View all articles
# </a>, <a class="btn btn-primary btn-md" href="/membership/basic-letter/" onclick="ga('send', 'event', 'Blog link', 'Click free template signup 2', 'Digital marketing strategy');">
# Get FREE templates
# </a>, <a class="author-link" href="https://www.smartinsights.com/author/gavinllewellyn/">
# By Gavin Llewellyn </a>, <a class="blog_link" href="https://www.smartinsights.com/internet-advertising/custom-audiences-and-identity-based-targeting/" title="Custom audiences and identity-based targeting"><h5>Custom audiences and identity-based targeting</h5>
# <p>A step-by-step approach to using identity-based targeting to drive relevance for your digital ad campaigns One of the huge advantages that digital advertising has promised marketers is the ability to target audiences more precisely and deliver personalized content and creative. …..</p>
# <span class="clear"></span>
# </a>, <a href="/internet-advertising-targeting">
# Internet ad targeting </a>, <a class="author-link" href="https://www.smartinsights.com/author/guest-expert/">
# By Expert commentator </a>, <a class="blog_link" href="https://www.smartinsights.com/internet-advertising/secrets-to-successful-mobile-app-ad-campaign-launch/" title="Secrets to a successful mobile app ad campaign launch"><h5>Secrets to a successful mobile app ad campaign launch</h5>
# <p>The successful launch of a new mobile app ad campaign requires a targeted UAC approach When launching a new mobile app, you may not have an advertising account history to leverage or a customer list to create a lookalike audience …..</p>
# <span class="clear"></span>
# </a>, <a href="/internet-advertising">
# Internet advertising </a>, <a class="author-link" href="https://www.smartinsights.com/author/joannatipton_/">
# By Joanna Carter </a>, <a class="blog_link" href="https://www.smartinsights.com/internet-advertising/internet-advertising-strategy/33-will-click-paid-ads-answer-search-query/" title="33% will click on paid ads that answer their search query"><h5>33% will click on paid ads that answer their search query</h5>
# <p>Chart of the week: People are happy to trust a paid ad if it seems to provide the answer they are looking for A third (33%) of people will click on a paid search ad because it directly answers their …..</p>
# <span class="clear"></span>
# </a>, <a href="/internet-advertising-strategy">
# Internet advertising strategy </a>, <a class="author-link" href="https://www.smartinsights.com/author/davechaffey/">
# By Dave Chaffey </a>, <a class="blog_link" href="https://www.smartinsights.com/mobile-marketing/mobile-marketing-analytics/mobile-marketing-statistics/" title="Mobile marketing statistics compilation"><h5>Mobile marketing statistics compilation</h5>
# <p>Statistics on consumer mobile usage and adoption to inform your mobile marketing strategy mobile site design and app development “Mobile to overtake fixed Internet access by 2014” was the huge headline summarizing the bold prediction from 2008 by Mary Meeker, …..</p>
# <span class="clear"></span>
# </a>, <a href="/mobile-marketing-analytics">
# Mobile marketing analytics </a>, <a class="author-link" href="https://www.smartinsights.com/author/davechaffey/">
# By Dave Chaffey </a>, <a class="blog_link" href="https://www.smartinsights.com/social-media-marketing/social-media-strategy/new-global-social-media-research/" title="Global social media research summary 2019"><h5>Global social media research summary 2019</h5>
# <p>Our compilation of the latest social media statistics of consumer adoption and usage Social networks are now so well established, that there is a core ‘top five’ social networks that don’t change much from year-to-year. But, as we’ll see in …..</p>
# <span class="clear"></span>
# </a>, <a href="/social-media-strategy">
# Social media strategy </a>, <a class="author-link" href="https://www.smartinsights.com/author/davechaffey/">
# By Dave Chaffey </a>, <a class="blog_link" href="https://www.smartinsights.com/digital-marketing-strategy/online-business-revenue-models/amazon-case-study/" title="Amazon.com case study – 2018 update"><h5>Amazon.com case study – 2018 update</h5>
# <p>Amazon’s business strategy, revenue model and culture of metrics: a history I’ve used Amazon as a case study in my books for nearly 20 years now since I think all types of businesses can learn from their digital business strategy. From startups …..</p>
# <span class="clear"></span>
# </a>, <a href="/online-business-revenue-models">
# Online business and revenue mo... </a>, <a href="/about/">About</a>, <a href="/contact-us/">Contact us</a>, <a href="/digital-marketing-strategy/digital-strategy-development/marketing-manifesto/">Our manifesto</a>, <a href="/content-partnership-enquiry/">Partnerships</a>, <a href="/training/">Training</a>, <a href="/consultancy/">Consulting</a>, <a href="/membership/">Member options</a>, <a href="/membership/membership-pricing/">Member pricing</a>, <a href="/digital-marketing-advice/">Member resources</a>, <a href="/support/faq/">Support and FAQ</a>, <a href="/membership/e-membership/">Premium membership</a>, <a href="/membership/team-membership-enquiry/">Business membership</a>, <a href="/membership/basic-letter/">Free resources</a>, <a href="/digital-marketing-advice/">Premium resources</a>, <a href="/digital-marketing-advice/?resource=template">Templates</a>, <a href="/digital-marketing-advice/?resource=ebook">Ebooks</a>, <a href="/guides/digital-marketing-elearning/">Elearning</a>, <a href="/quick-wins/">Quick Wins</a>, <a href="/improve/digital-marketing-strategy-planning-toolkit/">Digital marketing strategy</a>, <a href="/improve/digital-transformation-toolkit/">Digital transformation</a>, <a href="/improve/multichannel-lifecycle-marketing/">Lifecycle marketing</a>, <a href="/improve/agency-growth-management-toolkit/">Agency growth</a>, <a href="/improve/managing-digital-marketing-teams/">Managing digital teams</a>, <a href="/guides/digital-marketing-strategy-guide-7-steps-to-success/">RACE Planning framework</a>, <a href="/improve/marketing-campaign-planning-toolkit/">Campaign planning</a>, <a href="/improve/content-marketing-toolkit/">Content marketing</a>, <a href="/improve/ecommerce-retail-digital-marketing/">Ecommerce</a>, <a href="/improve/email-marketing-toolkit/">Email marketing</a>, <a href="/improve/search-engine-optimisation-seo-toolkit/">Search Engine Optimization</a>, <a href="/improve/social-media-marketing-toolkit/">Social media marketing</a>, <a href="/improve/digital-experience-management-toolkit/">User experience and CRO</a>, <a class="icon-linkedin" href="https://www.linkedin.com/company/smart-insights-marketing-intelligence-limited" title="Connect with us on Linked In"><span>Linked In</span></a>, <a class="icon-facebook" href="https://www.facebook.com/pages/Smart-Insights/102173513156313" title="Join us on Facebook"><span>Facebook</span></a>, <a class="icon-twitter" href="https://www.twitter.com/smartinsights" title="Follow us on Twitter"><span>Twitter</span></a>, <a class="icon-instagram" href="https://www.instagram.com/smart_insights/" title="Follow us on Instagram"><span>Instagram</span></a>, <a class="icon-rss" href="https://feeds.feedburner.com/smartinsights" title="Subscribe to our RSS feed"><span>RSS Feed</span></a>, <a href="https://www.smartinsights.com">Smart Insights (Marketing Intelligence) Ltd</a>, <a href="/terms">Terms</a>, <a href="/privacy">Privacy Policy</a>, <a href="/privacy/#cookieuse">cookie-use</a>], 239, 0.012445971983544237, 53)

# %%
crawler.master_dict['Title_Text'][0]
# Out:
# 'Travel Tips: 67 cheap holiday tricks for overseas - MSE'

# %%
soup = BeautifulSoup(response)

# %%
#Get Title Tag Of Page
title_text = soup.title.getText()

#Title Tag Length In Characters
title_tag_length = len(title_text)

# %%
# First get the meta description tag
description = soup.find('meta', attrs={'name':'og:description'}) or soup.find('meta', attrs={'property':'description'}) or soup.find('meta', attrs={'name':'description'})

# If description meta tag was found, then get the content attribute and save it to db entry
if description:
    meta_description = description.get('content')

# %%
#Extracting Visible Text From The Webpage

# kill all script and style elements
for script in soup(["script", "style"]):
    script.extract()    # rip it out

# get text
text = soup.body.get_text()

# break into lines and remove leading and trailing space on each
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)

# %%
#Word Length of The Webpage
word_length = len(text)

# %%
#Number of Links
body_links = soup.body.find_all('a')
number_of_links = len(body_links)

# %%
number_of_links
# Out:
# 353

# %%
#Links To Text Ratio
links_to_text_ratio = len(body_links) / word_length

# %%
#Number of Images
Number_of_images = len([imgtag for imgtag in soup.body.find_all('img')])

# %%
#Create A DataFrame Here!!!

df = pd.Series({'Title_Tag': title_text, 
                   'Title_Tag_Length':title_tag_length, 
                   'Meta_Description':meta_description,
                   'Body_Content_Text':text,
                   'Word_Length': word_length,
                   '<a>_Links_In_Body': number_of_links,
                   'Links_To_Text_Ratio': links_to_text_ratio,
                   'Number_Of_Images': Number_of_images,
                   'URL': test_url
    
})

# %%
df
# Out:
# Title_Tag                           Submit Listing | Eastern Daily Press
# Title_Tag_Length                                                      36
# Meta_Description       News, sport, entertainment and community infor...
# Body_Content_Text      Register\nLog in | Register\nJobs24\nLocalsear...
# Word_Length                                                         6241
# <a>_Links_In_Body                                                    353
# Links_To_Text_Ratio                                            0.0565614
# Number_Of_Images                                                      18
# URL                     https://www.edp24.co.uk/going-out/submit-listing
# dtype: object

# %%
def dummy_variables(url):
    
    if 'blog' in url:
        df['Blog_In_URL'] = 1
    else: 
        df['Blog_In_URL'] = 0    
            
    if 'community' in url:
        df['Community_In_URL'] = 1
    else: 
        df['Community_In_URL'] = 0
        
    if ('directory' in url) or ('listing' in url):
        df['Directory'] = 1
    else: 
        df['Directory'] = 0
        
    if ('links' in url) or ('resources' in url):
        df['Links_In_URL'] = 1
    else: 
        df['Links_In_URL'] = 0

# %%
dummy_variables(df['URL'])

# %%
#Header Code

h1_text = soup.h1
number_of_h1 = len(soup.h1)

h2_text = soup.h2.getText()
number_of_h2 = len(soup.h2)

h3_text = soup.h3.getText()
number_of_h3 = len(soup.h3)

h4_text = soup.h4.getText()
number_of_h4 = len(soup.h4)

# %%
df['h1_text'] = h1_text
df['h2_text'] = h2_text
df['h3_text'] = h3_text
df['h4_text'] = h4_text

# %%
# Out:
# [nltk_data] Downloading package punkt to C:\Users\james.DESKTOP-36N7TS
# [nltk_data]     Q\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
sentences = nltk.sent_tokenize(text)

# %%
test_url
# Out:
# 'https://www.edp24.co.uk/going-out/submit-listing'

# %%
#Readability Scores For A Given Textual Input

lexicon_count = textstat.lexicon_count(text, removepunct=True)
number_of_sentences = len(sentences)
Flesch_Reading_Ease_formula = textstat.flesch_reading_ease(text)
Flesch_Kincaid_Grade_Level = textstat.flesch_kincaid_grade(text)
FOG_Scale = textstat.gunning_fog(text)
SMOG_Index = textstat.smog_index(text)
ARI_Index = textstat.automated_readability_index(text)

# %%
#Page_Size_In_Bytes
page_size_in_bytes = len(req.content)

#Plain_text_size
plain_text_size = len(text)

#plain_text_rate --> plaintext rate value (plain_text_size / page_size)
plain_text_rate = (plain_text_size / page_size_in_bytes) * 100

# %%
#Encoding 
encoding = req.encoding
# Out:
# 'utf-8'

# %%
#Status_Code
status_code = req.status_code

# %% [markdown]
# seo_friendly_url_characters_check -- checking for symbols in accordance with Google recommendations only uppercase and lowercase Latin characters, digits and dashes are allowed ‘true’ - if the test is passed.

# %%
seo_list = ascii_letters + ascii_lowercase + ascii_uppercase + digits + extra_chars
ascii_letters = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'
ascii_lowercase = 'abcdefghijklmnopqrstuvwxyz'
ascii_uppercase = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
digits = '0123456789'
extra_chars = '.|-'
    
new_url = []

for character in awesome:
    if character in seo_list:
        new_url.append(character)

if len(new_url) == len(awesome):
    print(True)
else:
    print(False)
# Out:
# True

# %%
#seo_friendly_url_relative_length_check - url should not be longer than 120 characters      
if len(url) < 120:
    return True
else: 
    return False

# %%
#Check 

if url.contains('')

# %%
# check the actual URL for the site (SSL Encrypted)

if 's' in req.url:
    return True
else:
    return False
# Out:
# https://
