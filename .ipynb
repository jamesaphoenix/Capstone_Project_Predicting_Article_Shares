# %%
from IPython.display import Image

# %%
Image(filename='seo-use-cases-ml.png')

# %% [markdown]
# <strong> Useful Blog Posts </strong>
# - https://www.searchviu.com/en/machine-learning-seo-predicting-rankings/
# - https://www.ovh.com/world/news/articles/al464.ranking-predict-seo-data-leading-edge-search
# - https://searchengineland.com/experiment-trying-predict-google-rankings-253621
# - https://data-seo.com/2018/11/27/successfully-predicting-google-rankings-data-science/

# %% [markdown]
# <strong> GitHub's To Help With Predictive SEO </strong>
# - https://github.com/ovh/summit2016-RankingPredict/blob/master/README.md
# - https://github.com/searchVIU/Labs

# %% [markdown]
# <strong> Potentially Helpful APIs </strong>
# - https://github.com/MLTSEO/MLTS/blob/master/Tutorials/Sklearn/PythonforSEOTechSEOBoost2018_Hamlet_Batista.ipynb
# - https://github.com/ibebeebz/google-natural-language-api

# %% [markdown]
# <strong> Heplful Authors </strong>
# - Hamlet Batista - https://www.searchenginejournal.com/author/hamlet-batista/
# - https://searchenginewatch.com/author/hamletbatista/
# - https://www.aira.net/blog/how-to-automatically-categorise-keywords-for-the-buyers-journey/

# %% [markdown]
# <strong> Useful APIS </strong>
# - https://dataforseo.com/
# - https://github.com/clips/pattern

# %% [markdown]
# Pre-trained Datasets
# - https://github.com/ovh/summit2016-RankingPredict/tree/master/dataset

# %% [markdown]
# ## Questions To Answer
#
# -------
#
# <span style='font-size:18px;'> 1. For one specific domain/website, given if we know all of the keywords, landing pages and 3 - 4 competitors. What are the best pages to adjust for additional search traffic? Additionally what are the best new keywords that should be chosen for when creating new content for Google Search via SEO? </span>
#
# - Predictors: [Keyword in Content, Keyword in Domain, Search Volume, Cost Per Click]
#
# - Target Variable: Position
#
# - Chosen Website:
#
# -------
#
# <span style='font-size:18px;'> 2. Can we create a Google prediction search ranking algorithim that focuses on whether the given result + keyword will appear on the first page of Google? (This will be a binary classification algorithim). </span>
#
# - Predictors:
#
# - Target Variable:
#
# - Metrics:
#
# - Dataset:
#
# -------
#
# <span style='font-size:18px;'> 3. Create An Unsupervised Clustering Model That Helps To Predict When A Webpage Has A Poor CTR (%) due to the title tag or meta description tag. </span>
#
# <img src='CTR-clustering.png' />
#
# - Chosen Website: https://buffert.se/, a swedish finance website with 12.7 million impressions and 756,000 organic clicks within the last 12 months.
